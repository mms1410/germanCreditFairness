# %%
from adsssds_project.data import get_german_credit
from adsssds_project.plots import plot_categories, plot_numerical
from matplotlib import pyplot as plt
import seaborn as sns

# %%
german_credit = get_german_credit()
credit = german_credit.frame
credit
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0         6  critical/other existing credit
# 1          0<=X<200        48                   existing paid
# 2       no checking        12  critical/other existing credit
# 3                <0        42                   existing paid
# 4                <0        24              delayed previously
# ..              ...       ...                             ...
# 995     no checking        12                   existing paid
# 996              <0        30                   existing paid
# 997     no checking        12                   existing paid
# 998              <0        45                   existing paid
# 999        0<=X<200        45  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv           1169  no known savings         >=7
# 1               radio/tv           5951              <100      1<=X<4
# ...

# %%
print(credit.num_dependents.value_counts())
print(credit.existing_credits.value_counts())
print(credit.residence_since.value_counts())
print(credit.installment_commitment.value_counts())
to_category = ["num_dependents", "existing_credits", "residence_since", "installment_commitment"]
for column_name in to_category:
    credit[column_name] = credit[column_name].astype("category")
# Out:
# num_dependents
# 1    845
# 2    155
# Name: count, dtype: int64
# existing_credits
# 1    633
# 2    333
# 3     28
# 4      6
# Name: count, dtype: int64
# residence_since
# 4    413
# 2    308
# 3    149
# 1    130
# Name: count, dtype: int64
# installment_commitment
# 4    476
# 2    231
# 3    157
# 1    136
# Name: count, dtype: int64

# %%
categories = credit.select_dtypes(include="category")
n_categories = categories.shape[1]
n_categories
# Out:
# 18

# %%
cat_melt = categories.melt(var_name = "category", value_name = "value")

# %%
numerics = credit.select_dtypes(include="number")
n_numerics = numerics.shape[1]
n_numerics
# Out:
# 3

# %%
numerics_melt = numerics.melt(var_name = "variable", value_name = "value")

# %%
_ = plot_categories(credit)

# %%
_ = plot_numerical(credit)
